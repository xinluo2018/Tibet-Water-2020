# %%
import os
os.chdir('..') 
from visual import config
from utils.geotif_io import readTiff
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
path_as = config.root_proj + '/data/dset/s1_ascend/s1_as_scene_01.tif'
path_des = config.root_proj + '/data/dset/s1_descend/s1_des_scene_01.tif'
path_truth = config.root_proj + '/data/dset/s1_truth/s1_scene_01_truth.tif'
path_as
# Out:
# '/Users/luo/Downloads/Monthly-Surface-Water-in-Tibet/data/dset/s1_ascend/s1_as_scene_01.tif'

# %%
s1_as, s1_as_info = readTiff(path_as)
truth, truth_info = readTiff(path_truth)

# %%
colors = ['white', 'blue'] 
cmap = mpl.colors.ListedColormap(colors)

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.imshow(s1_as[:,:,0], cmap ='gray', clim=[-40, 8])
plt.subplot(1,2,2)
plt.imshow(truth, cmap=cmap)

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.imshow(s1_as[758:2798, 808:2848, 0], cmap ='gray', clim=[-40, 8])
plt.subplot(2,2,2)
plt.imshow(s1_as[1522:2034, 1572:2084, 0], cmap ='gray', clim=[-40, 8])
plt.subplot(2,2,3)
plt.imshow(s1_as[1650:1906, 1700:1956, 0], cmap ='gray', clim=[-40, 8])

plt.subplot(2,2,4)
plt.imshow(truth[1650:1906, 1700:1956], cmap=cmap)

# %%
plt.hist(s1_as[:,:,0].ravel(), bins=100);
